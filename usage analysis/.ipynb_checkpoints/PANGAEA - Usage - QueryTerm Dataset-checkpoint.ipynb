# %%
import sys
import os
import bz2
from bz2 import BZ2File
import io
import csv
import glob
import pandas as pd
from datetime import datetime
import pytz
import numpy as np
import re
from urllib import parse
from furl import furl
from itertools import tee
pd.options.mode.chained_assignment = None

# %%
path = "pangaea_usage"
filename_prefix = "doi.pangaea.de-access."
file_type=".bz2"

# %%
def parse_str(x):
    """
    Returns the string delimited by two characters.
    Example:`>>> parse_str('[my string]')``'my string'`"""
    if x:
        return x[1:-1]
    else:
        return x

# %%
dfs = []
for file in os.listdir(path):
    if file.startswith(filename_prefix) and file.endswith(file_type):
        filepath = os.path.join(path, file)
        print(filepath)
        data = pd.read_csv(filepath, compression='bz2',encoding = 'ISO-8859-1',
                           sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])', engine='python', na_values='-',header=0,
                           usecols=[0, 3, 4, 5, 7, 8],names=['ip', 'time', 'request', 'status', 'referer', 'user_agent'],
                           converters={'request': parse_str,'referer': parse_str,'user_agent': parse_str})
        dfs.append(data)

# Concatenate all data into one DataFrame
dfmain = pd.concat(dfs, ignore_index=True)
# Out:
# pangaea_usage\doi.pangaea.de-access.201707020000.bz2
# pangaea_usage\doi.pangaea.de-access.201707090000.bz2
# pangaea_usage\doi.pangaea.de-access.201707160000.bz2
# pangaea_usage\doi.pangaea.de-access.201707230000.bz2
# pangaea_usage\doi.pangaea.de-access.201707300000.bz2
# pangaea_usage\doi.pangaea.de-access.201708060000.bz2
# pangaea_usage\doi.pangaea.de-access.201708130000.bz2
# pangaea_usage\doi.pangaea.de-access.201708200000.bz2
# pangaea_usage\doi.pangaea.de-access.201708270000.bz2
# pangaea_usage\doi.pangaea.de-access.201709030000.bz2
# pangaea_usage\doi.pangaea.de-access.201709100000.bz2
# pangaea_usage\doi.pangaea.de-access.201709170000.bz2
# pangaea_usage\doi.pangaea.de-access.201709240000.bz2
# pangaea_usage\doi.pangaea.de-access.201710010000.bz2
# pangaea_usage\doi.pangaea.de-access.201710080000.bz2
# pangaea_usage\doi.pangaea.de-access.201710150000.bz2
# pangaea_usage\doi.pangaea.de-access.201710220000.bz2
# pangaea_usage\doi.pangaea.de-access.201710290000.bz2

# %%
dfmain.shape
# Out:
# (7790569, 6)

# %%
#Get resource URI
request = dfmain.request.str.split()
dfmain['resource'] = request.str[1]
#Filter out non GET and non 200 requests
dfmain = dfmain[(request.str[0] == 'GET') & (dfmain.status == 200)]
dfmain.shape
# Out:
# (4333633, 7)

# %%
#undesired resources
dfmain = dfmain[~dfmain['request'].str.match(r'^/media|^/static|^/admin|^/robots.txt$|^/favicon.ico$')]
#filter crawlers by User-Agent
dfmain = dfmain[~dfmain['user_agent'].str.match(r'.*?bot|.*?spider|.*?crawler|.*?slurp', flags=re.I).fillna(False)]
dfmain.shape
# Out:
# (1856766, 7)

# %%
#remove referer == NaN
dfmain = dfmain.dropna(subset=['referer'])   
# only include referer from pangaea
domains = ['doi.pangaea.de', 'www.pangaea.de']
domains_joins = '|'.join(map(re.escape, domains))
dfmain = dfmain[(dfmain.referer.str.contains(domains_joins))]  
dfmain = dfmain[(dfmain.referer.str.contains('google') != True)]  
dfmain.shape
# Out:
# (99459, 7)

# %%
#test only
m = pd.DataFrame({'Page URL':['GET /doi%3A10.1594/PANGAEA.134142?format=events_kml', '/10.1594/PANGAEA.55907?format=events_kml&',
                                   '/10.1594/PANGAEA.809526','/','/10.1594/PANGAEA.864108 HTTP/1.1']})
m['SubDomain'] = m['Page URL'].str.extract(r'PANGAEA.\s*([^\n? ]+)',expand=False)
m.head()
# Out:
#                                             Page URL SubDomain
# 0  GET /doi%3A10.1594/PANGAEA.134142?format=event...    134142
# 1          /10.1594/PANGAEA.55907?format=events_kml&     55907
# 2                            /10.1594/PANGAEA.809526    809526
# 3                                                  /       NaN
# 4                   /10.1594/PANGAEA.864108 HTTP/1.1    864108

# %%
dfmain['status'] = dfmain['status'].astype(int)

# %%
#convert status to int
dfmain.loc[dfmain['status'] != 200]['status'].unique()
# Out:
# array([], dtype=int64)

# %%
#get resource uri
dfmain['_id'] = dfmain['request'].str.extract(r'PANGAEA.\s*([^\n? ]+)',expand=False)
#remove rows if dataset is NaN
dfmain = dfmain.dropna(subset=['_id'], how='all')
dfmain.shape
# Out:
# (98355, 8)

# %%
#dfmain['_id'] = pd.to_numeric(dfmain['_id'], errors='coerce')
dfmain.head()
# Out:
#                   ip                          time  \
# 26    128.111.108.83  [25/Jun/2017:00:01:09 +0000]
# 547    82.211.205.99  [25/Jun/2017:00:18:38 +0000]
# 991    220.233.25.35  [25/Jun/2017:00:36:21 +0000]
# 1697    71.63.93.182  [25/Jun/2017:00:48:39 +0000]
# 1703    71.63.93.182  [25/Jun/2017:00:48:53 +0000]
#
#                                                 request  status  \
# 26                 GET /10.1594/PANGAEA.849518 HTTP/1.1     200
# 547    GET /10.1594/PANGAEA.811931?format=html HTTP/1.1     200
# 991   GET /10.1594/PANGAEA.786470?format=zip&charset...     200
# 1697               GET /10.1594/PANGAEA.844808 HTTP/1.1     200
# 1703  GET /10.1594/PANGAEA.844808?format=zip&charset...     200
#
#                                                 referer  \
# 26            https://www.pangaea.de/?q=Weldeab%2C+Syee
# 547       https://doi.pangaea.de/10.1594/PANGAEA.811931
# 991       https://doi.pangaea.de/10.1594/PANGAEA.786470
# 1697  https://www.pangaea.de/?q=shale&f.pubyear%5B%5...
# 1703      https://doi.pangaea.de/10.1594/PANGAEA.844808
#
#                                              user_agent  \
# 26    Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...
# 547   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 991   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
# 1697  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
# 1703  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
#
#                                               resource     _id
# 26                             /10.1594/PANGAEA.849518  849518
# 547                /10.1594/PANGAEA.811931?format=html  811931
# 991   /10.1594/PANGAEA.786470?format=zip&charset=UTF-8  786470
# 1697                           /10.1594/PANGAEA.844808  844808
# 1703  /10.1594/PANGAEA.844808?format=zip&charset=UTF-8  844808

# %%
#dfmain = dfmain[~dfmain['ip'].str.startswith('X.X.X.')]

# %%
def get_query(url):
    qparams = dict(parse.parse_qsl(parse.urlsplit(url).query))
    query_string= ""
    if len(qparams)>0:
        for key in qparams:
            if re.match(r'f[.]|q|t', key):
                query_string += qparams[key] + " "
    return query_string

# %%
#first degree queries
dfmain['query_1']=dfmain['referer'].map(get_query)

# %%
"" in dfmain.query_1.unique(), " " in dfmain.query_1.unique()
# Out:
# (True, False)

# %%
#convert time to datetime type
dfmain['time'] = dfmain['time'].str.strip('[]').str[:-6]
dfmain['time'] = pd.to_datetime(dfmain['time'], format='%d/%b/%Y:%H:%M:%S')

# %%
dfmain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98355 entries, 26 to 7790534
# Data columns (total 9 columns):
# ip            98355 non-null object
# time          98355 non-null datetime64[ns]
# request       98355 non-null object
# status        98355 non-null int32
# referer       98355 non-null object
# user_agent    98349 non-null object
# resource      98355 non-null object
# _id           98355 non-null object
# query_1       98355 non-null object
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 7.1+ MB

# %%
dfmain['time_normalize'] = dfmain['time'].dt.date
#dfmain['time_normalize']=dfmain['time'].dt.round('720min')  
dfmain.head()
# Out:
#                   ip                time  \
# 26    128.111.108.83 2017-06-25 00:01:09
# 547    82.211.205.99 2017-06-25 00:18:38
# 991    220.233.25.35 2017-06-25 00:36:21
# 1697    71.63.93.182 2017-06-25 00:48:39
# 1703    71.63.93.182 2017-06-25 00:48:53
#
#                                                 request  status  \
# 26                 GET /10.1594/PANGAEA.849518 HTTP/1.1     200
# 547    GET /10.1594/PANGAEA.811931?format=html HTTP/1.1     200
# 991   GET /10.1594/PANGAEA.786470?format=zip&charset...     200
# 1697               GET /10.1594/PANGAEA.844808 HTTP/1.1     200
# 1703  GET /10.1594/PANGAEA.844808?format=zip&charset...     200
#
#                                                 referer  \
# 26            https://www.pangaea.de/?q=Weldeab%2C+Syee
# 547       https://doi.pangaea.de/10.1594/PANGAEA.811931
# 991       https://doi.pangaea.de/10.1594/PANGAEA.786470
# 1697  https://www.pangaea.de/?q=shale&f.pubyear%5B%5...
# 1703      https://doi.pangaea.de/10.1594/PANGAEA.844808
#
#                                              user_agent  \
# 26    Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...
# 547   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 991   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
# 1697  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
# 1703  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...
#
#                                               resource     _id  \
# 26                             /10.1594/PANGAEA.849518  849518
# 547                /10.1594/PANGAEA.811931?format=html  811931
# 991   /10.1594/PANGAEA.786470?format=zip&charset=UTF-8  786470
# 1697                           /10.1594/PANGAEA.844808  844808
# 1703  /10.1594/PANGAEA.844808?format=zip&charset=UTF-8  844808
#
#              query_1 time_normalize
# 26    Weldeab, Syee      2017-06-25
# 547                      2017-06-25
# 991                      2017-06-25
# 1697     shale 2015      2017-06-25
# 1703                     2017-06-25

# %%
dfmain.ix[dfmain['_id']=='875146']['referer']
# Out:
# Series([], Name: referer, dtype: object)

# %%
dfmain['query_2'] = ""
dfmain = dfmain[['ip','time','_id','query_1','query_2','time_normalize']]

# %%
dfmain.shape
# Out:
# (98355, 6)

# %%
dfmain.head(15)
# Out:
#                   ip                time     _id  \
# 26    128.111.108.83 2017-06-25 00:01:09  849518
# 547    82.211.205.99 2017-06-25 00:18:38  811931
# 991    220.233.25.35 2017-06-25 00:36:21  786470
# 1697    71.63.93.182 2017-06-25 00:48:39  844808
# 1703    71.63.93.182 2017-06-25 00:48:53  844808
# 1713    71.63.93.182 2017-06-25 00:49:42  847486
# 1779    71.63.93.182 2017-06-25 00:52:20  780208
# 1813    71.63.93.182 2017-06-25 00:53:59  780208
# 1875    71.63.93.182 2017-06-25 00:56:25  707379
# 1887    71.63.93.182 2017-06-25 00:56:42  707378
# 1892    71.63.93.182 2017-06-25 00:56:48  707378
# 1898    71.63.93.182 2017-06-25 00:57:08  707377
# 1900    71.63.93.182 2017-06-25 00:57:12  707377
# 1990    71.63.93.182 2017-06-25 01:00:49  777673
# 2015    71.63.93.182 2017-06-25 01:01:42  841464
#
#                                 query_1 query_2 time_normalize
# 26                       Weldeab, Syee              2017-06-25
# 547                                                 2017-06-25
# 991                                                 2017-06-25
# 1697                        shale 2015              2017-06-25
# 1703                                                2017-06-25
# 1713                        shale 2015              2017-06-25
# 1779  shale gechemistry Chemistry 2011              2017-06-25
# 1813                                                2017-06-25
# 1875  shale gechemistry Chemistry 1988              2017-06-25
# 1887                                                2017-06-25
# 1892                                                2017-06-25
# 1898                                                2017-06-25
# 1900                                                2017-06-25
# 1990                          brumsack              2017-06-25
# 2015                          brumsack              2017-06-25

# %%
first = dfmain.groupby(by=['ip','time_normalize'])
first_filtered = first.filter(lambda x: len(x[x['query_1'] != ""]) >0)
first_filtered.head(20)
# Out:
#                    ip                time     _id  \
# 26     128.111.108.83 2017-06-25 00:01:09  849518
# 1697     71.63.93.182 2017-06-25 00:48:39  844808
# 1703     71.63.93.182 2017-06-25 00:48:53  844808
# 1713     71.63.93.182 2017-06-25 00:49:42  847486
# 1779     71.63.93.182 2017-06-25 00:52:20  780208
# 1813     71.63.93.182 2017-06-25 00:53:59  780208
# 1875     71.63.93.182 2017-06-25 00:56:25  707379
# 1887     71.63.93.182 2017-06-25 00:56:42  707378
# 1892     71.63.93.182 2017-06-25 00:56:48  707378
# 1898     71.63.93.182 2017-06-25 00:57:08  707377
# 1900     71.63.93.182 2017-06-25 00:57:12  707377
# 1990     71.63.93.182 2017-06-25 01:00:49  777673
# 2015     71.63.93.182 2017-06-25 01:01:42  841464
# 2673   128.111.108.83 2017-06-25 01:32:59  849518
# 16251   101.182.90.38 2017-06-25 03:20:04  874930
# 44454    5.113.84.127 2017-06-25 04:11:47  792618
# 58595  147.237.70.107 2017-06-25 06:09:46  874610
# 58609  147.237.70.107 2017-06-25 06:10:07  669510
# 58616  147.237.70.107 2017-06-25 06:10:23  669510
# 58630  147.237.70.107 2017-06-25 06:10:48  669510
#
#                                                  query_1 query_2  \
# 26                                        Weldeab, Syee
# 1697                                         shale 2015
# 1703
# 1713                                         shale 2015
# 1779                   shale gechemistry Chemistry 2011
# 1813
# 1875                   shale gechemistry Chemistry 1988
# 1887
# 1892
# 1898
# 1900
# 1990                                           brumsack
# 2015                                           brumsack
# 2673                                      Weldeab, Syee
# 16251                                          thurstan
# 44454                                   Atmosphere BSRN
# 58595  project:label:BSRN +event:label:BER +citation:...
# 58609
# 58616
# 58630
#
#            time_normalize
# 26    2017-06-25 00:00:00
# 1697  2017-06-25 00:00:00
# 1703  2017-06-25 00:00:00
# 1713  2017-06-25 00:00:00
# 1779  2017-06-25 00:00:00
# 1813  2017-06-25 00:00:00
# 1875  2017-06-25 00:00:00
# 1887  2017-06-25 00:00:00
# 1892  2017-06-25 00:00:00
# 1898  2017-06-25 00:00:00
# 1900  2017-06-25 00:00:00
# 1990  2017-06-25 00:00:00
# 2015  2017-06-25 00:00:00
# 2673  2017-06-25 00:00:00
# 16251 2017-06-25 00:00:00
# 44454 2017-06-25 00:00:00
# 58595 2017-06-25 12:00:00
# 58609 2017-06-25 12:00:00
# 58616 2017-06-25 12:00:00
# 58630 2017-06-25 12:00:00

# %%
second = first_filtered.groupby(by=['ip','time_normalize'])
filtered = second.filter(lambda x: len(x[x['query_1'] == ""]) >0)
filtered.head(20)
# Out:
#                    ip                time     _id  \
# 1697     71.63.93.182 2017-06-25 00:48:39  844808
# 1703     71.63.93.182 2017-06-25 00:48:53  844808
# 1713     71.63.93.182 2017-06-25 00:49:42  847486
# 1779     71.63.93.182 2017-06-25 00:52:20  780208
# 1813     71.63.93.182 2017-06-25 00:53:59  780208
# 1875     71.63.93.182 2017-06-25 00:56:25  707379
# 1887     71.63.93.182 2017-06-25 00:56:42  707378
# 1892     71.63.93.182 2017-06-25 00:56:48  707378
# 1898     71.63.93.182 2017-06-25 00:57:08  707377
# 1900     71.63.93.182 2017-06-25 00:57:12  707377
# 1990     71.63.93.182 2017-06-25 01:00:49  777673
# 2015     71.63.93.182 2017-06-25 01:01:42  841464
# 58595  147.237.70.107 2017-06-25 06:09:46  874610
# 58609  147.237.70.107 2017-06-25 06:10:07  669510
# 58616  147.237.70.107 2017-06-25 06:10:23  669510
# 58630  147.237.70.107 2017-06-25 06:10:48  669510
# 58842  147.237.70.107 2017-06-25 06:16:57  669510
# 58843  147.237.70.107 2017-06-25 06:17:00  669510
# 59978   86.203.81.125 2017-06-25 06:56:58  859074
# 60491   31.10.163.139 2017-06-25 07:17:35  792619
#
#                                                  query_1 query_2  \
# 1697                                         shale 2015
# 1703
# 1713                                         shale 2015
# 1779                   shale gechemistry Chemistry 2011
# 1813
# 1875                   shale gechemistry Chemistry 1988
# 1887
# 1892
# 1898
# 1900
# 1990                                           brumsack
# 2015                                           brumsack
# 58595  project:label:BSRN +event:label:BER +citation:...
# 58609
# 58616
# 58630
# 58842
# 58843
# 59978
# 60491                                   roelfsema heron
#
#            time_normalize
# 1697  2017-06-25 00:00:00
# 1703  2017-06-25 00:00:00
# 1713  2017-06-25 00:00:00
# 1779  2017-06-25 00:00:00
# 1813  2017-06-25 00:00:00
# 1875  2017-06-25 00:00:00
# 1887  2017-06-25 00:00:00
# 1892  2017-06-25 00:00:00
# 1898  2017-06-25 00:00:00
# 1900  2017-06-25 00:00:00
# 1990  2017-06-25 00:00:00
# 2015  2017-06-25 00:00:00
# 58595 2017-06-25 12:00:00
# 58609 2017-06-25 12:00:00
# 58616 2017-06-25 12:00:00
# 58630 2017-06-25 12:00:00
# 58842 2017-06-25 12:00:00
# 58843 2017-06-25 12:00:00
# 59978 2017-06-25 12:00:00
# 60491 2017-06-25 12:00:00

# %%
#second_filters = filtered_notnull.groupby(['ip','time_normalize'])['query_1'].filter(lambda x: len(x == "") > 0)
#filtered = filtered_notnull[filtered_notnull['query_1'].isin(second_filters)]
#filtered.head(20)

# %%
#groups_final = filtered_notnull.groupby(by=['ip','time_normalize'])
#filtered = groups_final.filter(lambda x: len(x[x['query_1'] == None]) >0)
#filtered.head(20)

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
for (i1, row1), (i2, row2) in pairwise(filtered.iterrows()):
    if ((row1["query_1"] != "") and (row2["query_1"] == "")):
        filtered.set_value(i2, 'query_2', row1["query_1"])
        #filtered.loc[i2, 'query_2'] = row1["query_1"]

# %%
filtered.head(20)
# Out:
#                    ip                time     _id  \
# 1697     71.63.93.182 2017-06-25 00:48:39  844808
# 1703     71.63.93.182 2017-06-25 00:48:53  844808
# 1713     71.63.93.182 2017-06-25 00:49:42  847486
# 1779     71.63.93.182 2017-06-25 00:52:20  780208
# 1813     71.63.93.182 2017-06-25 00:53:59  780208
# 1875     71.63.93.182 2017-06-25 00:56:25  707379
# 1887     71.63.93.182 2017-06-25 00:56:42  707378
# 1892     71.63.93.182 2017-06-25 00:56:48  707378
# 1898     71.63.93.182 2017-06-25 00:57:08  707377
# 1900     71.63.93.182 2017-06-25 00:57:12  707377
# 1990     71.63.93.182 2017-06-25 01:00:49  777673
# 2015     71.63.93.182 2017-06-25 01:01:42  841464
# 58595  147.237.70.107 2017-06-25 06:09:46  874610
# 58609  147.237.70.107 2017-06-25 06:10:07  669510
# 58616  147.237.70.107 2017-06-25 06:10:23  669510
# 58630  147.237.70.107 2017-06-25 06:10:48  669510
# 58842  147.237.70.107 2017-06-25 06:16:57  669510
# 58843  147.237.70.107 2017-06-25 06:17:00  669510
# 59978   86.203.81.125 2017-06-25 06:56:58  859074
# 60491   31.10.163.139 2017-06-25 07:17:35  792619
#
#                                                  query_1  \
# 1697                                         shale 2015
# 1703
# 1713                                         shale 2015
# 1779                   shale gechemistry Chemistry 2011
# 1813
# 1875                   shale gechemistry Chemistry 1988
# 1887
# 1892
# 1898
# 1900
# 1990                                           brumsack
# 2015                                           brumsack
# 58595  project:label:BSRN +event:label:BER +citation:...
# 58609
# 58616
# 58630
# 58842
# 58843
# 59978
# 60491                                   roelfsema heron
#
#                                                  query_2      time_normalize
# 1697                                                     2017-06-25 00:00:00
# 1703                                         shale 2015  2017-06-25 00:00:00
# 1713                                                     2017-06-25 00:00:00
# 1779                                                     2017-06-25 00:00:00
# 1813                   shale gechemistry Chemistry 2011  2017-06-25 00:00:00
# 1875                                                     2017-06-25 00:00:00
# 1887                   shale gechemistry Chemistry 1988  2017-06-25 00:00:00
# 1892                                                     2017-06-25 00:00:00
# 1898                                                     2017-06-25 00:00:00
# 1900                                                     2017-06-25 00:00:00
# 1990                                                     2017-06-25 00:00:00
# 2015                                                     2017-06-25 00:00:00
# 58595                                                    2017-06-25 12:00:00
# 58609  project:label:BSRN +event:label:BER +citation:... 2017-06-25 12:00:00
# 58616                                                    2017-06-25 12:00:00
# 58630                                                    2017-06-25 12:00:00
# 58842                                                    2017-06-25 12:00:00
# 58843                                                    2017-06-25 12:00:00
# 59978                                                    2017-06-25 12:00:00
# 60491                                                    2017-06-25 12:00:00

# %%
filtered.shape
# Out:
# (60283, 6)

# %%
filtered = filtered[~((filtered.query_1 == "") & (filtered.query_2 == ""))]

# %%
filtered.shape
# Out:
# (40289, 6)

# %%
filtered.head(10)
# Out:
#                    ip                time     _id  \
# 1697     71.63.93.182 2017-06-25 00:48:39  844808
# 1703     71.63.93.182 2017-06-25 00:48:53  844808
# 1713     71.63.93.182 2017-06-25 00:49:42  847486
# 1779     71.63.93.182 2017-06-25 00:52:20  780208
# 1813     71.63.93.182 2017-06-25 00:53:59  780208
# 1875     71.63.93.182 2017-06-25 00:56:25  707379
# 1887     71.63.93.182 2017-06-25 00:56:42  707378
# 1990     71.63.93.182 2017-06-25 01:00:49  777673
# 2015     71.63.93.182 2017-06-25 01:01:42  841464
# 58595  147.237.70.107 2017-06-25 06:09:46  874610
#
#                                                  query_1  \
# 1697                                         shale 2015
# 1703
# 1713                                         shale 2015
# 1779                   shale gechemistry Chemistry 2011
# 1813
# 1875                   shale gechemistry Chemistry 1988
# 1887
# 1990                                           brumsack
# 2015                                           brumsack
# 58595  project:label:BSRN +event:label:BER +citation:...
#
#                                  query_2      time_normalize
# 1697                                     2017-06-25 00:00:00
# 1703                         shale 2015  2017-06-25 00:00:00
# 1713                                     2017-06-25 00:00:00
# 1779                                     2017-06-25 00:00:00
# 1813   shale gechemistry Chemistry 2011  2017-06-25 00:00:00
# 1875                                     2017-06-25 00:00:00
# 1887   shale gechemistry Chemistry 1988  2017-06-25 00:00:00
# 1990                                     2017-06-25 00:00:00
# 2015                                     2017-06-25 00:00:00
# 58595                                    2017-06-25 12:00:00

# %%
filtered._id.nunique()
# Out:
# 17661

# %%
dfgroup = filtered.groupby('_id')['query_1','query_2'].apply(lambda x: x.sum())
dfgroup.head()
# Out:
#                                                query_1  \
# _id
# 100217  pronephrium parameter:"Pronephrium stiriacum"
# 101315                                  49-410 49-410
# 101477
# 101481        fruela Oceans Hespérides Southern Ocean
# 101499                                       ps2778-2
#
#                         query_2
# _id
# 100217
# 101315                  49-410
# 101477  antarctica CTD/Rosette
# 101481
# 101499

# %%
filtered[filtered._id=='100217']
# Out:
#                     ip                time     _id  \
# 5851343  210.72.92.164 2017-09-11 04:51:19  100217
# 5851524  210.72.92.164 2017-09-11 05:02:16  100217
#
#                                     query_1 query_2 time_normalize
# 5851343                        pronephrium              2017-09-11
# 5851524  parameter:"Pronephrium stiriacum"              2017-09-11

# %%
#strip white spaces
dfgroup['query_1'] = dfgroup['query_1'].str.strip()
dfgroup['query_2'] = dfgroup['query_2'].str.strip()
dfgroup.head()
# Out:
#                                               query_1                 query_2
# _id
# 100217  pronephrium parameter:"Pronephrium stiriacum"
# 101315                                  49-410 49-410                  49-410
# 101477                                                 antarctica CTD/Rosette
# 101481        fruela Oceans Hespérides Southern Ocean
# 101499                                       ps2778-2

# %%
dfgroup.ix[dfgroup.query_2 =="", 'query_2'] = None
dfgroup.ix[dfgroup.query_1 =="", 'query_1'] = None

# %%
dfgroup.reset_index().to_json(path+'/query_data_rel.json',orient='records')
